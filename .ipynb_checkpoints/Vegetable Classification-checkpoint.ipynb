# %%
from google.colab import drive #importing drive content
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %tensorflow_version 2.x  ##Checking if GPU is working or not
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
import matplotlib.pyplot as plt #importing necessary library
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib ##setting directory for train data
data_dir = "/content/drive/MyDrive/AI/Vegetable Classification/Vegetable Classification/Train"
data_dir = pathlib.Path(data_dir)

# %%
image_count = len(list(data_dir.glob('*/*.jpg'))) ##counting train data
print(image_count)
# Out:
# 6673

# %%
Tomato = list(data_dir.glob('Tomato/*')) ##showing train data part of data visualization
PIL.Image.open(str(Tomato[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x100 at 0x7F621124DF90>

# %%
PIL.Image.open(str(Tomato[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x100 at 0x7F62114A8F90>

# %%
Potato = list(data_dir.glob('Potato/*'))
PIL.Image.open(str(Potato[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x100 at 0x7F62114A8950>

# %%
PIL.Image.open(str(Potato[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x100 at 0x7F62112C0550>

# %% [markdown]
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6673 files belonging to 5 classes.
# Using 5339 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6673 files belonging to 5 classes.
# Using 1334 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Bell-Pepper', 'Lemon', 'Onion', 'Potato', 'Tomato']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 180, 180, 3)
# (32,)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
normalization_layer = layers.Rescaling(1./255)

# %%
num_classes = len(class_names) ## creating model

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',  ##using optimizer adam and loss function categorical crossentropy
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()  ##showing model summary
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 5)                 645
#
# ...
# Total params: 3,989,285
# Trainable params: 3,989,285
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=10      ##Running epoch
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 167/167 [==============================] - 164s 930ms/step - loss: 0.2593 - accuracy: 0.9116 - val_loss: 0.1364 - val_accuracy: 0.9423
# Epoch 2/10
# 167/167 [==============================] - 8s 46ms/step - loss: 0.0191 - accuracy: 0.9934 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 3/10
# 167/167 [==============================] - 8s 45ms/step - loss: 9.2468e-04 - accuracy: 0.9994 - val_loss: 3.2559e-04 - val_accuracy: 1.0000
# Epoch 4/10
# 167/167 [==============================] - 8s 45ms/step - loss: 1.7201e-04 - accuracy: 1.0000 - val_loss: 1.4746e-04 - val_accuracy: 1.0000
# Epoch 5/10
# 167/167 [==============================] - 7s 45ms/step - loss: 1.4606e-04 - accuracy: 1.0000 - val_loss: 8.7680e-05 - val_accuracy: 1.0000
# Epoch 6/10
# 167/167 [==============================] - 7s 45ms/step - loss: 5.9787e-05 - accuracy: 1.0000 - val_loss: 5.2859e-05 - val_accuracy: 1.0000
# Epoch 7/10
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
data_augmentation = keras.Sequential(  ##data augmentation for overfitting
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
model = Sequential([   ##creating model
  data_augmentation, 
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary() ##model summary
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 180, 180, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 90, 90, 16)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_4 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 22, 22, 64)        0
#
#  flatten_1 (Flatten)         (None, 30976)             0
#
#  dense_2 (Dense)             (None, 128)               3965056
#
#  dense_3 (Dense)             (None, 5)                 645
#
# ...
# Total params: 3,989,285
# Trainable params: 3,989,285
# ...

# %%
epochs = 15    ## runing epoch for training and validation
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/15
# 167/167 [==============================] - 11s 60ms/step - loss: 0.3371 - accuracy: 0.8655 - val_loss: 0.0243 - val_accuracy: 0.9948
# Epoch 2/15
# 167/167 [==============================] - 8s 51ms/step - loss: 0.0265 - accuracy: 0.9918 - val_loss: 0.0503 - val_accuracy: 0.9753
# Epoch 3/15
# 167/167 [==============================] - 8s 51ms/step - loss: 0.0258 - accuracy: 0.9916 - val_loss: 0.0078 - val_accuracy: 0.9970
# Epoch 4/15
# 167/167 [==============================] - 8s 51ms/step - loss: 0.0803 - accuracy: 0.9757 - val_loss: 0.0129 - val_accuracy: 0.9978
# Epoch 5/15
# 167/167 [==============================] - 8s 51ms/step - loss: 0.0200 - accuracy: 0.9933 - val_loss: 0.0092 - val_accuracy: 0.9978
# Epoch 6/15
# 167/167 [==============================] - 9s 51ms/step - loss: 0.0143 - accuracy: 0.9946 - val_loss: 0.0064 - val_accuracy: 0.9970
# Epoch 7/15
# ...

# %%
acc = history.history['accuracy']      ## creating accuracy and loss chart
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
test_path = "/content/drive/MyDrive/AI/Vegetable Classification/Vegetable Classification/Test/13_100(1).jpg" ## testing using given image

img = tf.keras.utils.load_img(test_path, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely belongs to Bell-Pepper with a 100.00 percent confidence.

# %%
test_path = "/content/drive/MyDrive/AI/Vegetable Classification/Vegetable Classification/Test/26_100(1).jpg"

img = tf.keras.utils.load_img(test_path, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely belongs to Potato with a 99.99 percent confidence.

# %%
test_path = "/content/drive/MyDrive/AI/Vegetable Classification/Vegetable Classification/Test/75_100(1).jpg"

img = tf.keras.utils.load_img(test_path, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely belongs to Tomato with a 100.00 percent confidence.

# %%
test_path = "/content/drive/MyDrive/AI/Vegetable Classification/Vegetable Classification/Test/9_100(1).jpg"

img = tf.keras.utils.load_img(test_path, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely belongs to Lemon with a 100.00 percent confidence.
